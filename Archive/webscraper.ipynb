# %%
import pandas as pd 
import yfinance as yf 

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

#read wikipedia S&P500 table into PD dataframe 
df_sp500 = pd.read_html(url)[0][['Symbol', 'Security', 'GICS Sector']] 
#ticker DF 
sp500_tickers = df_sp500['Symbol'].tolist() 

#read changes table into DF 
sp500_changes = pd.read_html(url)[1]

#problematic 
# drop rows where at least one ellement missing
#changes = df_changes[['Date', 'Added', 'Removed']].dropna() 
#filter out reasons column 
#changes = changes[~changes['Date'].str.contains('Reason')]
#filter out note column 
#changes = changes[~changes['Date'].str.contains('Note')] 

#leaving these fuckers out (Berkshire Hathaway - 2010, Brown-Forman - 1982, AirBNB - 2023)
exclude = ['BRK.B', 'BF.B', 'ABNB', 'CARR', 'CEG', 'CTVA', 'DOW', 'FOXA', 'FOX', 'GEHC', 'KVUE', 'OTIS', 'UBER', 'VLTO'] 
sp500_tickers = [ticker for ticker in sp500_tickers if ticker not in exclude]

#dict for individual stock DF storage 
stockdataframes = {} 

start_dte = "2023-01-01"
end_dte = "2023-12-31"

#ADD INCLUSION AND EXCLUSION DATE AND FILTER BY THAT FOR NEWER STOCKS AND REMOVED ONES 

#iterate through all tickers+ get historical data 
for ticker in sp500_tickers: 
    #added = row['Added'] 
    #removed = row['Removed'] 
    
    try:
        stock = yf.Ticker(ticker) 
        stock_df = stock.history(start=start_dte, end=end_dte)[['Close']]
        
        #debug 
        print(f"Debug - Ticker: {ticker}, DataFrame shape: {stock_df.shape}")
        
        #merge with wiki data - check if not empty first
        if 'Close' in stock_df.columns and not stock_df.empty: 
            stock_df['Symbol'] = ticker
            stock_df['Security'] = df_sp500[df_sp500['Symbol'] == ticker]['Security'].iloc[0]
            stock_df['GICS Sector'] = df_sp500[df_sp500['Symbol'] == ticker]['GICS Sector'].iloc[0]
            #merged_stock_df = pd.merge(stock_df, df_sp500[df_sp500['Symbol'] == ticker], left_index=True, right_index=True)
        
            #store merged df in dictionary 
            stockdataframes[ticker] = stock_df #used o be merged_stock_dataframe
        
            print(f"Data fetched for {ticker}")
        else:
            print(f"Failed to fetch data for {ticker}: {e}")
    except Exception as e: 
        print(f"Failed to fetch data for {ticker}: {e}")

#merge all stock dfs into one 
full_df = pd.concat(stockdataframes.values(), keys=stockdataframes.keys())

#ptiny 
print(full_df.head())
# Out:
# Debug - Ticker: MMM, DataFrame shape: (250, 1)
# Data fetched for MMM
# Debug - Ticker: AOS, DataFrame shape: (250, 1)
# Data fetched for AOS
# Debug - Ticker: ABT, DataFrame shape: (250, 1)
# Data fetched for ABT
# Debug - Ticker: ABBV, DataFrame shape: (250, 1)
# Data fetched for ABBV
# Debug - Ticker: ACN, DataFrame shape: (250, 1)
# Data fetched for ACN
# Debug - Ticker: ADBE, DataFrame shape: (250, 1)
# Data fetched for ADBE
# Debug - Ticker: AMD, DataFrame shape: (250, 1)
# Data fetched for AMD
# Debug - Ticker: AES, DataFrame shape: (250, 1)
# Data fetched for AES
# Debug - Ticker: AFL, DataFrame shape: (250, 1)
# Data fetched for AFL
# Debug - Ticker: A, DataFrame shape: (250, 1)
# Data fetched for A
# Debug - Ticker: APD, DataFrame shape: (250, 1)
# Data fetched for APD
# Debug - Ticker: AKAM, DataFrame shape: (250, 1)
# Data fetched for AKAM
# Debug - Ticker: ALB, DataFrame shape: (250, 1)
# Data fetched for ALB
# Debug - Ticker: ARE, DataFrame shape: (250, 1)
# Data fetched for ARE
# Debug - Ticker: ALGN, DataFrame shape: (250, 1)
# Data fetched for ALGN
# Debug - Ticker: ALLE, DataFrame shape: (250, 1)
# Data fetched for ALLE
# Debug - Ticker: LNT, DataFrame shape: (250, 1)
# Data fetched for LNT
# Debug - Ticker: ALL, DataFrame shape: (250, 1)
# Data fetched for ALL
# Debug - Ticker: GOOGL, DataFrame shape: (250, 1)
# Data fetched for GOOGL
# Debug - Ticker: GOOG, DataFrame shape: (250, 1)
# Data fetched for GOOG
# Debug - Ticker: MO, DataFrame shape: (250, 1)
# Data fetched for MO
# Debug - Ticker: AMZN, DataFrame shape: (250, 1)
# Data fetched for AMZN
# Debug - Ticker: AMCR, DataFrame shape: (250, 1)
# Data fetched for AMCR
# Debug - Ticker: AEE, DataFrame shape: (250, 1)
# Data fetched for AEE
# Debug - Ticker: AAL, DataFrame shape: (250, 1)
# Data fetched for AAL
# Debug - Ticker: AEP, DataFrame shape: (250, 1)
# Data fetched for AEP
# Debug - Ticker: AXP, DataFrame shape: (250, 1)
# Data fetched for AXP
# Debug - Ticker: AIG, DataFrame shape: (250, 1)
# Data fetched for AIG
# Debug - Ticker: AMT, DataFrame shape: (250, 1)
# Data fetched for AMT
# Debug - Ticker: AWK, DataFrame shape: (250, 1)
# Data fetched for AWK
# Debug - Ticker: AMP, DataFrame shape: (250, 1)
# Data fetched for AMP
# Debug - Ticker: AME, DataFrame shape: (250, 1)
# Data fetched for AME
# Debug - Ticker: AMGN, DataFrame shape: (250, 1)
# Data fetched for AMGN
# Debug - Ticker: APH, DataFrame shape: (250, 1)
# Data fetched for APH
# Debug - Ticker: ADI, DataFrame shape: (250, 1)
# Data fetched for ADI
# Debug - Ticker: ANSS, DataFrame shape: (250, 1)
# Data fetched for ANSS
# Debug - Ticker: AON, DataFrame shape: (250, 1)
# Data fetched for AON
# Debug - Ticker: APA, DataFrame shape: (250, 1)
# Data fetched for APA
# Debug - Ticker: AAPL, DataFrame shape: (250, 1)
# Data fetched for AAPL
# Debug - Ticker: AMAT, DataFrame shape: (250, 1)
# Data fetched for AMAT
# Debug - Ticker: APTV, DataFrame shape: (250, 1)
# Data fetched for APTV
# Debug - Ticker: ACGL, DataFrame shape: (250, 1)
# Data fetched for ACGL
# Debug - Ticker: ADM, DataFrame shape: (250, 1)
# Data fetched for ADM
# Debug - Ticker: ANET, DataFrame shape: (250, 1)
# Data fetched for ANET
# Debug - Ticker: AJG, DataFrame shape: (250, 1)
# Data fetched for AJG
# Debug - Ticker: AIZ, DataFrame shape: (250, 1)
# Data fetched for AIZ
# Debug - Ticker: T, DataFrame shape: (250, 1)
# Data fetched for T
# Debug - Ticker: ATO, DataFrame shape: (250, 1)
# Data fetched for ATO
# Debug - Ticker: ADSK, DataFrame shape: (250, 1)
# Data fetched for ADSK
# Debug - Ticker: ADP, DataFrame shape: (250, 1)
# Data fetched for ADP
# Debug - Ticker: AZO, DataFrame shape: (250, 1)
# Data fetched for AZO
# Debug - Ticker: AVB, DataFrame shape: (250, 1)
# Data fetched for AVB
# Debug - Ticker: AVY, DataFrame shape: (250, 1)
# Data fetched for AVY
# Debug - Ticker: AXON, DataFrame shape: (250, 1)
# Data fetched for AXON
# Debug - Ticker: BKR, DataFrame shape: (250, 1)
# Data fetched for BKR
# Debug - Ticker: BALL, DataFrame shape: (250, 1)
# Data fetched for BALL
# Debug - Ticker: BAC, DataFrame shape: (250, 1)
# Data fetched for BAC
# Debug - Ticker: BK, DataFrame shape: (250, 1)
# Data fetched for BK
# Debug - Ticker: BBWI, DataFrame shape: (250, 1)
# Data fetched for BBWI
# Debug - Ticker: BAX, DataFrame shape: (250, 1)
# Data fetched for BAX
# Debug - Ticker: BDX, DataFrame shape: (250, 1)
# Data fetched for BDX
# Debug - Ticker: BBY, DataFrame shape: (250, 1)
# Data fetched for BBY
# Debug - Ticker: BIO, DataFrame shape: (250, 1)
# Data fetched for BIO
# Debug - Ticker: TECH, DataFrame shape: (250, 1)
# Data fetched for TECH
# Debug - Ticker: BIIB, DataFrame shape: (250, 1)
# Data fetched for BIIB
# Debug - Ticker: BLK, DataFrame shape: (250, 1)
# Data fetched for BLK
# Debug - Ticker: BX, DataFrame shape: (250, 1)
# Data fetched for BX
# Debug - Ticker: BA, DataFrame shape: (250, 1)
# Data fetched for BA
# Debug - Ticker: BKNG, DataFrame shape: (250, 1)
# Data fetched for BKNG
# Debug - Ticker: BWA, DataFrame shape: (250, 1)
# Data fetched for BWA
# Debug - Ticker: BXP, DataFrame shape: (250, 1)
# Data fetched for BXP
# Debug - Ticker: BSX, DataFrame shape: (250, 1)
# Data fetched for BSX
# Debug - Ticker: BMY, DataFrame shape: (250, 1)
# Data fetched for BMY
# Debug - Ticker: AVGO, DataFrame shape: (250, 1)
# Data fetched for AVGO
# Debug - Ticker: BR, DataFrame shape: (250, 1)
# Data fetched for BR
# Debug - Ticker: BRO, DataFrame shape: (250, 1)
# Data fetched for BRO
# Debug - Ticker: BLDR, DataFrame shape: (250, 1)
# Data fetched for BLDR
# Debug - Ticker: BG, DataFrame shape: (250, 1)
# Data fetched for BG
# Debug - Ticker: CDNS, DataFrame shape: (250, 1)
# Data fetched for CDNS
# Debug - Ticker: CZR, DataFrame shape: (250, 1)
# Data fetched for CZR
# Debug - Ticker: CPT, DataFrame shape: (250, 1)
# Data fetched for CPT
# Debug - Ticker: CPB, DataFrame shape: (250, 1)
# Data fetched for CPB
# Debug - Ticker: COF, DataFrame shape: (250, 1)
# Data fetched for COF
# Debug - Ticker: CAH, DataFrame shape: (250, 1)
# Data fetched for CAH
# Debug - Ticker: KMX, DataFrame shape: (250, 1)
# Data fetched for KMX
# Debug - Ticker: CCL, DataFrame shape: (250, 1)
# Data fetched for CCL
# Debug - Ticker: CTLT, DataFrame shape: (250, 1)
# Data fetched for CTLT
# Debug - Ticker: CAT, DataFrame shape: (250, 1)
# Data fetched for CAT
# Debug - Ticker: CBOE, DataFrame shape: (250, 1)
# Data fetched for CBOE
# Debug - Ticker: CBRE, DataFrame shape: (250, 1)
# Data fetched for CBRE
# Debug - Ticker: CDW, DataFrame shape: (250, 1)
# Data fetched for CDW
# Debug - Ticker: CE, DataFrame shape: (250, 1)
# Data fetched for CE
# Debug - Ticker: COR, DataFrame shape: (250, 1)
# Data fetched for COR
# Debug - Ticker: CNC, DataFrame shape: (250, 1)
# Data fetched for CNC
# Debug - Ticker: CNP, DataFrame shape: (250, 1)
# Data fetched for CNP
# Debug - Ticker: CF, DataFrame shape: (250, 1)
# Data fetched for CF
# Debug - Ticker: CHRW, DataFrame shape: (250, 1)
# Data fetched for CHRW
# Debug - Ticker: CRL, DataFrame shape: (250, 1)
# Data fetched for CRL
# Debug - Ticker: SCHW, DataFrame shape: (250, 1)
# Data fetched for SCHW
# Debug - Ticker: CHTR, DataFrame shape: (250, 1)
# Data fetched for CHTR
# Debug - Ticker: CVX, DataFrame shape: (250, 1)
# Data fetched for CVX
# Debug - Ticker: CMG, DataFrame shape: (250, 1)
# Data fetched for CMG
# Debug - Ticker: CB, DataFrame shape: (250, 1)
# Data fetched for CB
# Debug - Ticker: CHD, DataFrame shape: (250, 1)
# Data fetched for CHD
# Debug - Ticker: CI, DataFrame shape: (250, 1)
# Data fetched for CI
# Debug - Ticker: CINF, DataFrame shape: (250, 1)
# Data fetched for CINF
# Debug - Ticker: CTAS, DataFrame shape: (250, 1)
# Data fetched for CTAS
# Debug - Ticker: CSCO, DataFrame shape: (250, 1)
# Data fetched for CSCO
# Debug - Ticker: C, DataFrame shape: (250, 1)
# Data fetched for C
# Debug - Ticker: CFG, DataFrame shape: (250, 1)
# Data fetched for CFG
# Debug - Ticker: CLX, DataFrame shape: (250, 1)
# Data fetched for CLX
# Debug - Ticker: CME, DataFrame shape: (250, 1)
# Data fetched for CME
# Debug - Ticker: CMS, DataFrame shape: (250, 1)
# Data fetched for CMS
# Debug - Ticker: KO, DataFrame shape: (250, 1)
# Data fetched for KO
# Debug - Ticker: CTSH, DataFrame shape: (250, 1)
# Data fetched for CTSH
# Debug - Ticker: CL, DataFrame shape: (250, 1)
# Data fetched for CL
# Debug - Ticker: CMCSA, DataFrame shape: (250, 1)
# Data fetched for CMCSA
# Debug - Ticker: CMA, DataFrame shape: (250, 1)
# Data fetched for CMA
# Debug - Ticker: CAG, DataFrame shape: (250, 1)
# Data fetched for CAG
# Debug - Ticker: COP, DataFrame shape: (250, 1)
# Data fetched for COP
# Debug - Ticker: ED, DataFrame shape: (250, 1)
# Data fetched for ED
# Debug - Ticker: STZ, DataFrame shape: (250, 1)
# Data fetched for STZ
# Debug - Ticker: COO, DataFrame shape: (250, 1)
# Data fetched for COO
# Debug - Ticker: CPRT, DataFrame shape: (250, 1)
# Data fetched for CPRT
# Debug - Ticker: GLW, DataFrame shape: (250, 1)
# Data fetched for GLW
# Debug - Ticker: CSGP, DataFrame shape: (250, 1)
# Data fetched for CSGP
# Debug - Ticker: COST, DataFrame shape: (250, 1)
# Data fetched for COST
# Debug - Ticker: CTRA, DataFrame shape: (250, 1)
# Data fetched for CTRA
# Debug - Ticker: CCI, DataFrame shape: (250, 1)
# Data fetched for CCI
# Debug - Ticker: CSX, DataFrame shape: (250, 1)
# Data fetched for CSX
# Debug - Ticker: CMI, DataFrame shape: (250, 1)
# Data fetched for CMI
# Debug - Ticker: CVS, DataFrame shape: (250, 1)
# Data fetched for CVS
# Debug - Ticker: DHR, DataFrame shape: (250, 1)
# Data fetched for DHR
# Debug - Ticker: DRI, DataFrame shape: (250, 1)
# Data fetched for DRI
# Debug - Ticker: DVA, DataFrame shape: (250, 1)
# Data fetched for DVA
# Debug - Ticker: DAY, DataFrame shape: (250, 1)
# Data fetched for DAY
# Debug - Ticker: DE, DataFrame shape: (250, 1)
# Data fetched for DE
# Debug - Ticker: DAL, DataFrame shape: (250, 1)
# Data fetched for DAL
# Debug - Ticker: XRAY, DataFrame shape: (250, 1)
# Data fetched for XRAY
# Debug - Ticker: DVN, DataFrame shape: (250, 1)
# Data fetched for DVN
# Debug - Ticker: DXCM, DataFrame shape: (250, 1)
# Data fetched for DXCM
# Debug - Ticker: FANG, DataFrame shape: (250, 1)
# Data fetched for FANG
# Debug - Ticker: DLR, DataFrame shape: (250, 1)
# Data fetched for DLR
# Debug - Ticker: DFS, DataFrame shape: (250, 1)
# Data fetched for DFS
# Debug - Ticker: DG, DataFrame shape: (250, 1)
# Data fetched for DG
# Debug - Ticker: DLTR, DataFrame shape: (250, 1)
# Data fetched for DLTR
# Debug - Ticker: D, DataFrame shape: (250, 1)
# Data fetched for D
# Debug - Ticker: DPZ, DataFrame shape: (250, 1)
# Data fetched for DPZ
# Debug - Ticker: DOV, DataFrame shape: (250, 1)
# Data fetched for DOV
# Debug - Ticker: DHI, DataFrame shape: (250, 1)
# Data fetched for DHI
# Debug - Ticker: DTE, DataFrame shape: (250, 1)
# Data fetched for DTE
# Debug - Ticker: DUK, DataFrame shape: (250, 1)
# Data fetched for DUK
# Debug - Ticker: DD, DataFrame shape: (250, 1)
# Data fetched for DD
# Debug - Ticker: EMN, DataFrame shape: (250, 1)
# Data fetched for EMN
# Debug - Ticker: ETN, DataFrame shape: (250, 1)
# Data fetched for ETN
# Debug - Ticker: EBAY, DataFrame shape: (250, 1)
# Data fetched for EBAY
# Debug - Ticker: ECL, DataFrame shape: (250, 1)
# Data fetched for ECL
# Debug - Ticker: EIX, DataFrame shape: (250, 1)
# Data fetched for EIX
# Debug - Ticker: EW, DataFrame shape: (250, 1)
# Data fetched for EW
# Debug - Ticker: EA, DataFrame shape: (250, 1)
# Data fetched for EA
# Debug - Ticker: ELV, DataFrame shape: (250, 1)
# Data fetched for ELV
# Debug - Ticker: LLY, DataFrame shape: (250, 1)
# Data fetched for LLY
# Debug - Ticker: EMR, DataFrame shape: (250, 1)
# Data fetched for EMR
# Debug - Ticker: ENPH, DataFrame shape: (250, 1)
# Data fetched for ENPH
# Debug - Ticker: ETR, DataFrame shape: (250, 1)
# Data fetched for ETR
# Debug - Ticker: EOG, DataFrame shape: (250, 1)
# Data fetched for EOG
# Debug - Ticker: EPAM, DataFrame shape: (250, 1)
# Data fetched for EPAM
# Debug - Ticker: EQT, DataFrame shape: (250, 1)
# Data fetched for EQT
# Debug - Ticker: EFX, DataFrame shape: (250, 1)
# Data fetched for EFX
# Debug - Ticker: EQIX, DataFrame shape: (250, 1)
# Data fetched for EQIX
# Debug - Ticker: EQR, DataFrame shape: (250, 1)
# Data fetched for EQR
# Debug - Ticker: ESS, DataFrame shape: (250, 1)
# Data fetched for ESS
# Debug - Ticker: EL, DataFrame shape: (250, 1)
# Data fetched for EL
# Debug - Ticker: ETSY, DataFrame shape: (250, 1)
# Data fetched for ETSY
# Debug - Ticker: EG, DataFrame shape: (250, 1)
# Data fetched for EG
# Debug - Ticker: EVRG, DataFrame shape: (250, 1)
# Data fetched for EVRG
# Debug - Ticker: ES, DataFrame shape: (250, 1)
# Data fetched for ES
# Debug - Ticker: EXC, DataFrame shape: (250, 1)
# Data fetched for EXC
# Debug - Ticker: EXPE, DataFrame shape: (250, 1)
# Data fetched for EXPE
# Debug - Ticker: EXPD, DataFrame shape: (250, 1)
# Data fetched for EXPD
# Debug - Ticker: EXR, DataFrame shape: (250, 1)
# Data fetched for EXR
# Debug - Ticker: XOM, DataFrame shape: (250, 1)
# Data fetched for XOM
# Debug - Ticker: FFIV, DataFrame shape: (250, 1)
# Data fetched for FFIV
# Debug - Ticker: FDS, DataFrame shape: (250, 1)
# Data fetched for FDS
# Debug - Ticker: FICO, DataFrame shape: (250, 1)
# Data fetched for FICO
# Debug - Ticker: FAST, DataFrame shape: (250, 1)
# Data fetched for FAST
# Debug - Ticker: FRT, DataFrame shape: (250, 1)
# Data fetched for FRT
# Debug - Ticker: FDX, DataFrame shape: (250, 1)
# Data fetched for FDX
# Debug - Ticker: FIS, DataFrame shape: (250, 1)
# Data fetched for FIS
# Debug - Ticker: FITB, DataFrame shape: (250, 1)
# Data fetched for FITB
# Debug - Ticker: FSLR, DataFrame shape: (250, 1)
# Data fetched for FSLR
# Debug - Ticker: FE, DataFrame shape: (250, 1)
# Data fetched for FE
# Debug - Ticker: FI, DataFrame shape: (250, 1)
# Data fetched for FI
# Debug - Ticker: FLT, DataFrame shape: (250, 1)
# Data fetched for FLT
# Debug - Ticker: FMC, DataFrame shape: (250, 1)
# Data fetched for FMC
# Debug - Ticker: F, DataFrame shape: (250, 1)
# Data fetched for F
# Debug - Ticker: FTNT, DataFrame shape: (250, 1)
# Data fetched for FTNT
# Debug - Ticker: FTV, DataFrame shape: (250, 1)
# Data fetched for FTV
# Debug - Ticker: BEN, DataFrame shape: (250, 1)
# Data fetched for BEN
# Debug - Ticker: FCX, DataFrame shape: (250, 1)
# Data fetched for FCX
# Debug - Ticker: GRMN, DataFrame shape: (250, 1)
# Data fetched for GRMN
# Debug - Ticker: IT, DataFrame shape: (250, 1)
# Data fetched for IT
# Debug - Ticker: GEN, DataFrame shape: (250, 1)
# Data fetched for GEN
# Debug - Ticker: GNRC, DataFrame shape: (250, 1)
# Data fetched for GNRC
# Debug - Ticker: GD, DataFrame shape: (250, 1)
# Data fetched for GD
# Debug - Ticker: GE, DataFrame shape: (250, 1)
# Data fetched for GE
# Debug - Ticker: GIS, DataFrame shape: (250, 1)
# Data fetched for GIS
# Debug - Ticker: GM, DataFrame shape: (250, 1)
# Data fetched for GM
# Debug - Ticker: GPC, DataFrame shape: (250, 1)
# Data fetched for GPC
# Debug - Ticker: GILD, DataFrame shape: (250, 1)
# Data fetched for GILD
# Debug - Ticker: GPN, DataFrame shape: (250, 1)
# Data fetched for GPN
# Debug - Ticker: GL, DataFrame shape: (250, 1)
# Data fetched for GL
# Debug - Ticker: GS, DataFrame shape: (250, 1)
# Data fetched for GS
# Debug - Ticker: HAL, DataFrame shape: (250, 1)
# Data fetched for HAL
# Debug - Ticker: HIG, DataFrame shape: (250, 1)
# Data fetched for HIG
# Debug - Ticker: HAS, DataFrame shape: (250, 1)
# Data fetched for HAS
# Debug - Ticker: HCA, DataFrame shape: (250, 1)
# Data fetched for HCA
# Debug - Ticker: PEAK, DataFrame shape: (250, 1)
# Data fetched for PEAK
# Debug - Ticker: HSIC, DataFrame shape: (250, 1)
# Data fetched for HSIC
# Debug - Ticker: HSY, DataFrame shape: (250, 1)
# Data fetched for HSY
# Debug - Ticker: HES, DataFrame shape: (250, 1)
# Data fetched for HES
# Debug - Ticker: HPE, DataFrame shape: (250, 1)
# Data fetched for HPE
# Debug - Ticker: HLT, DataFrame shape: (250, 1)
# Data fetched for HLT
# Debug - Ticker: HOLX, DataFrame shape: (250, 1)
# Data fetched for HOLX
# Debug - Ticker: HD, DataFrame shape: (250, 1)
# Data fetched for HD
# Debug - Ticker: HON, DataFrame shape: (250, 1)
# Data fetched for HON
# Debug - Ticker: HRL, DataFrame shape: (250, 1)
# Data fetched for HRL
# Debug - Ticker: HST, DataFrame shape: (250, 1)
# Data fetched for HST
# Debug - Ticker: HWM, DataFrame shape: (250, 1)
# Data fetched for HWM
# Debug - Ticker: HPQ, DataFrame shape: (250, 1)
# Data fetched for HPQ
# Debug - Ticker: HUBB, DataFrame shape: (250, 1)
# Data fetched for HUBB
# Debug - Ticker: HUM, DataFrame shape: (250, 1)
# Data fetched for HUM
# Debug - Ticker: HBAN, DataFrame shape: (250, 1)
# Data fetched for HBAN
# Debug - Ticker: HII, DataFrame shape: (250, 1)
# Data fetched for HII
# Debug - Ticker: IBM, DataFrame shape: (250, 1)
# Data fetched for IBM
# Debug - Ticker: IEX, DataFrame shape: (250, 1)
# Data fetched for IEX
# Debug - Ticker: IDXX, DataFrame shape: (250, 1)
# Data fetched for IDXX
# Debug - Ticker: ITW, DataFrame shape: (250, 1)
# Data fetched for ITW
# Debug - Ticker: ILMN, DataFrame shape: (250, 1)
# Data fetched for ILMN
# Debug - Ticker: INCY, DataFrame shape: (250, 1)
# Data fetched for INCY
# Debug - Ticker: IR, DataFrame shape: (250, 1)
# Data fetched for IR
# Debug - Ticker: PODD, DataFrame shape: (250, 1)
# Data fetched for PODD
# Debug - Ticker: INTC, DataFrame shape: (250, 1)
# Data fetched for INTC
# Debug - Ticker: ICE, DataFrame shape: (250, 1)
# Data fetched for ICE
# Debug - Ticker: IFF, DataFrame shape: (250, 1)
# Data fetched for IFF
# Debug - Ticker: IP, DataFrame shape: (250, 1)
# Data fetched for IP
# Debug - Ticker: IPG, DataFrame shape: (250, 1)
# Data fetched for IPG
# Debug - Ticker: INTU, DataFrame shape: (250, 1)
# Data fetched for INTU
# Debug - Ticker: ISRG, DataFrame shape: (250, 1)
# Data fetched for ISRG
# Debug - Ticker: IVZ, DataFrame shape: (250, 1)
# Data fetched for IVZ
# Debug - Ticker: INVH, DataFrame shape: (250, 1)
# Data fetched for INVH
# Debug - Ticker: IQV, DataFrame shape: (250, 1)
# Data fetched for IQV
# Debug - Ticker: IRM, DataFrame shape: (250, 1)
# Data fetched for IRM
# Debug - Ticker: JBHT, DataFrame shape: (250, 1)
# Data fetched for JBHT
# Debug - Ticker: JBL, DataFrame shape: (250, 1)
# Data fetched for JBL
# Debug - Ticker: JKHY, DataFrame shape: (250, 1)
# Data fetched for JKHY
# Debug - Ticker: J, DataFrame shape: (250, 1)
# Data fetched for J
# Debug - Ticker: JNJ, DataFrame shape: (250, 1)
# Data fetched for JNJ
# Debug - Ticker: JCI, DataFrame shape: (250, 1)
# Data fetched for JCI
# Debug - Ticker: JPM, DataFrame shape: (250, 1)
# Data fetched for JPM
# Debug - Ticker: JNPR, DataFrame shape: (250, 1)
# Data fetched for JNPR
# Debug - Ticker: K, DataFrame shape: (250, 1)
# Data fetched for K
# Debug - Ticker: KDP, DataFrame shape: (250, 1)
# Data fetched for KDP
# Debug - Ticker: KEY, DataFrame shape: (250, 1)
# Data fetched for KEY
# Debug - Ticker: KEYS, DataFrame shape: (250, 1)
# Data fetched for KEYS
# Debug - Ticker: KMB, DataFrame shape: (250, 1)
# Data fetched for KMB
# Debug - Ticker: KIM, DataFrame shape: (250, 1)
# Data fetched for KIM
# Debug - Ticker: KMI, DataFrame shape: (250, 1)
# Data fetched for KMI
# Debug - Ticker: KLAC, DataFrame shape: (250, 1)
# Data fetched for KLAC
# Debug - Ticker: KHC, DataFrame shape: (250, 1)
# Data fetched for KHC
# Debug - Ticker: KR, DataFrame shape: (250, 1)
# Data fetched for KR
# Debug - Ticker: LHX, DataFrame shape: (250, 1)
# Data fetched for LHX
# Debug - Ticker: LH, DataFrame shape: (250, 1)
# Data fetched for LH
# Debug - Ticker: LRCX, DataFrame shape: (250, 1)
# Data fetched for LRCX
# Debug - Ticker: LW, DataFrame shape: (250, 1)
# Data fetched for LW
# Debug - Ticker: LVS, DataFrame shape: (250, 1)
# Data fetched for LVS
# Debug - Ticker: LDOS, DataFrame shape: (250, 1)
# Data fetched for LDOS
# Debug - Ticker: LEN, DataFrame shape: (250, 1)
# Data fetched for LEN
# Debug - Ticker: LIN, DataFrame shape: (250, 1)
# Data fetched for LIN
# Debug - Ticker: LYV, DataFrame shape: (250, 1)
# Data fetched for LYV
# Debug - Ticker: LKQ, DataFrame shape: (250, 1)
# Data fetched for LKQ
# Debug - Ticker: LMT, DataFrame shape: (250, 1)
# Data fetched for LMT
# Debug - Ticker: L, DataFrame shape: (250, 1)
# Data fetched for L
# Debug - Ticker: LOW, DataFrame shape: (250, 1)
# Data fetched for LOW
# Debug - Ticker: LULU, DataFrame shape: (250, 1)
# Data fetched for LULU
# Debug - Ticker: LYB, DataFrame shape: (250, 1)
# Data fetched for LYB
# Debug - Ticker: MTB, DataFrame shape: (250, 1)
# Data fetched for MTB
# Debug - Ticker: MRO, DataFrame shape: (250, 1)
# Data fetched for MRO
# Debug - Ticker: MPC, DataFrame shape: (250, 1)
# Data fetched for MPC
# Debug - Ticker: MKTX, DataFrame shape: (250, 1)
# Data fetched for MKTX
# Debug - Ticker: MAR, DataFrame shape: (250, 1)
# Data fetched for MAR
# Debug - Ticker: MMC, DataFrame shape: (250, 1)
# Data fetched for MMC
# Debug - Ticker: MLM, DataFrame shape: (250, 1)
# Data fetched for MLM
# Debug - Ticker: MAS, DataFrame shape: (250, 1)
# Data fetched for MAS
# Debug - Ticker: MA, DataFrame shape: (250, 1)
# Data fetched for MA
# Debug - Ticker: MTCH, DataFrame shape: (250, 1)
# Data fetched for MTCH
# Debug - Ticker: MKC, DataFrame shape: (250, 1)
# Data fetched for MKC
# Debug - Ticker: MCD, DataFrame shape: (250, 1)
# Data fetched for MCD
# Debug - Ticker: MCK, DataFrame shape: (250, 1)
# Data fetched for MCK
# Debug - Ticker: MDT, DataFrame shape: (250, 1)
# Data fetched for MDT
# Debug - Ticker: MRK, DataFrame shape: (250, 1)
# Data fetched for MRK
# Debug - Ticker: META, DataFrame shape: (250, 1)
# Data fetched for META
# Debug - Ticker: MET, DataFrame shape: (250, 1)
# Data fetched for MET
# Debug - Ticker: MTD, DataFrame shape: (250, 1)
# Data fetched for MTD
# Debug - Ticker: MGM, DataFrame shape: (250, 1)
# Data fetched for MGM
# Debug - Ticker: MCHP, DataFrame shape: (250, 1)
# Data fetched for MCHP
# Debug - Ticker: MU, DataFrame shape: (250, 1)
# Data fetched for MU
# Debug - Ticker: MSFT, DataFrame shape: (250, 1)
# Data fetched for MSFT
# Debug - Ticker: MAA, DataFrame shape: (250, 1)
# Data fetched for MAA
# Debug - Ticker: MRNA, DataFrame shape: (250, 1)
# Data fetched for MRNA
# Debug - Ticker: MHK, DataFrame shape: (250, 1)
# Data fetched for MHK
# Debug - Ticker: MOH, DataFrame shape: (250, 1)
# Data fetched for MOH
# Debug - Ticker: TAP, DataFrame shape: (250, 1)
# Data fetched for TAP
# Debug - Ticker: MDLZ, DataFrame shape: (250, 1)
# Data fetched for MDLZ
# Debug - Ticker: MPWR, DataFrame shape: (250, 1)
# Data fetched for MPWR
# Debug - Ticker: MNST, DataFrame shape: (250, 1)
# Data fetched for MNST
# Debug - Ticker: MCO, DataFrame shape: (250, 1)
# Data fetched for MCO
# Debug - Ticker: MS, DataFrame shape: (250, 1)
# Data fetched for MS
# Debug - Ticker: MOS, DataFrame shape: (250, 1)
# Data fetched for MOS
# Debug - Ticker: MSI, DataFrame shape: (250, 1)
# Data fetched for MSI
# Debug - Ticker: MSCI, DataFrame shape: (250, 1)
# Data fetched for MSCI
# Debug - Ticker: NDAQ, DataFrame shape: (250, 1)
# Data fetched for NDAQ
# Debug - Ticker: NTAP, DataFrame shape: (250, 1)
# Data fetched for NTAP
# Debug - Ticker: NFLX, DataFrame shape: (250, 1)
# Data fetched for NFLX
# Debug - Ticker: NEM, DataFrame shape: (250, 1)
# Data fetched for NEM
# Debug - Ticker: NWSA, DataFrame shape: (250, 1)
# Data fetched for NWSA
# Debug - Ticker: NWS, DataFrame shape: (250, 1)
# Data fetched for NWS
# Debug - Ticker: NEE, DataFrame shape: (250, 1)
# Data fetched for NEE
# Debug - Ticker: NKE, DataFrame shape: (250, 1)
# Data fetched for NKE
# Debug - Ticker: NI, DataFrame shape: (250, 1)
# Data fetched for NI
# Debug - Ticker: NDSN, DataFrame shape: (250, 1)
# Data fetched for NDSN
# Debug - Ticker: NSC, DataFrame shape: (250, 1)
# Data fetched for NSC
# Debug - Ticker: NTRS, DataFrame shape: (250, 1)
# Data fetched for NTRS
# Debug - Ticker: NOC, DataFrame shape: (250, 1)
# Data fetched for NOC
# Debug - Ticker: NCLH, DataFrame shape: (250, 1)
# Data fetched for NCLH
# Debug - Ticker: NRG, DataFrame shape: (250, 1)
# Data fetched for NRG
# Debug - Ticker: NUE, DataFrame shape: (250, 1)
# Data fetched for NUE
# Debug - Ticker: NVDA, DataFrame shape: (250, 1)
# Data fetched for NVDA
# Debug - Ticker: NVR, DataFrame shape: (250, 1)
# Data fetched for NVR
# Debug - Ticker: NXPI, DataFrame shape: (250, 1)
# Data fetched for NXPI
# Debug - Ticker: ORLY, DataFrame shape: (250, 1)
# Data fetched for ORLY
# Debug - Ticker: OXY, DataFrame shape: (250, 1)
# Data fetched for OXY
# Debug - Ticker: ODFL, DataFrame shape: (250, 1)
# Data fetched for ODFL
# Debug - Ticker: OMC, DataFrame shape: (250, 1)
# Data fetched for OMC
# Debug - Ticker: ON, DataFrame shape: (250, 1)
# Data fetched for ON
# Debug - Ticker: OKE, DataFrame shape: (250, 1)
# Data fetched for OKE
# Debug - Ticker: ORCL, DataFrame shape: (250, 1)
# Data fetched for ORCL
# Debug - Ticker: PCAR, DataFrame shape: (250, 1)
# Data fetched for PCAR
# Debug - Ticker: PKG, DataFrame shape: (250, 1)
# Data fetched for PKG
# Debug - Ticker: PANW, DataFrame shape: (250, 1)
# Data fetched for PANW
# Debug - Ticker: PARA, DataFrame shape: (250, 1)
# Data fetched for PARA
# Debug - Ticker: PH, DataFrame shape: (250, 1)
# Data fetched for PH
# Debug - Ticker: PAYX, DataFrame shape: (250, 1)
# Data fetched for PAYX
# Debug - Ticker: PAYC, DataFrame shape: (250, 1)
# Data fetched for PAYC
# Debug - Ticker: PYPL, DataFrame shape: (250, 1)
# Data fetched for PYPL
# Debug - Ticker: PNR, DataFrame shape: (250, 1)
# Data fetched for PNR
# Debug - Ticker: PEP, DataFrame shape: (250, 1)
# Data fetched for PEP
# Debug - Ticker: PFE, DataFrame shape: (250, 1)
# Data fetched for PFE
# Debug - Ticker: PCG, DataFrame shape: (250, 1)
# Data fetched for PCG
# Debug - Ticker: PM, DataFrame shape: (250, 1)
# Data fetched for PM
# Debug - Ticker: PSX, DataFrame shape: (250, 1)
# Data fetched for PSX
# Debug - Ticker: PNW, DataFrame shape: (250, 1)
# Data fetched for PNW
# Debug - Ticker: PXD, DataFrame shape: (250, 1)
# Data fetched for PXD
# Debug - Ticker: PNC, DataFrame shape: (250, 1)
# Data fetched for PNC
# Debug - Ticker: POOL, DataFrame shape: (250, 1)
# Data fetched for POOL
# Debug - Ticker: PPG, DataFrame shape: (250, 1)
# Data fetched for PPG
# Debug - Ticker: PPL, DataFrame shape: (250, 1)
# Data fetched for PPL
# Debug - Ticker: PFG, DataFrame shape: (250, 1)
# Data fetched for PFG
# Debug - Ticker: PG, DataFrame shape: (250, 1)
# Data fetched for PG
# Debug - Ticker: PGR, DataFrame shape: (250, 1)
# Data fetched for PGR
# Debug - Ticker: PLD, DataFrame shape: (250, 1)
# Data fetched for PLD
# Debug - Ticker: PRU, DataFrame shape: (250, 1)
# Data fetched for PRU
# Debug - Ticker: PEG, DataFrame shape: (250, 1)
# Data fetched for PEG
# Debug - Ticker: PTC, DataFrame shape: (250, 1)
# Data fetched for PTC
# Debug - Ticker: PSA, DataFrame shape: (250, 1)
# Data fetched for PSA
# Debug - Ticker: PHM, DataFrame shape: (250, 1)
# Data fetched for PHM
# Debug - Ticker: QRVO, DataFrame shape: (250, 1)
# Data fetched for QRVO
# Debug - Ticker: PWR, DataFrame shape: (250, 1)
# Data fetched for PWR
# Debug - Ticker: QCOM, DataFrame shape: (250, 1)
# Data fetched for QCOM
# Debug - Ticker: DGX, DataFrame shape: (250, 1)
# Data fetched for DGX
# Debug - Ticker: RL, DataFrame shape: (250, 1)
# Data fetched for RL
# Debug - Ticker: RJF, DataFrame shape: (250, 1)
# Data fetched for RJF
# Debug - Ticker: RTX, DataFrame shape: (250, 1)
# Data fetched for RTX
# Debug - Ticker: O, DataFrame shape: (250, 1)
# Data fetched for O
# Debug - Ticker: REG, DataFrame shape: (250, 1)
# Data fetched for REG
# Debug - Ticker: REGN, DataFrame shape: (250, 1)
# Data fetched for REGN
# Debug - Ticker: RF, DataFrame shape: (250, 1)
# Data fetched for RF
# Debug - Ticker: RSG, DataFrame shape: (250, 1)
# Data fetched for RSG
# Debug - Ticker: RMD, DataFrame shape: (250, 1)
# Data fetched for RMD
# Debug - Ticker: RVTY, DataFrame shape: (250, 1)
# Data fetched for RVTY
# Debug - Ticker: RHI, DataFrame shape: (250, 1)
# Data fetched for RHI
# Debug - Ticker: ROK, DataFrame shape: (250, 1)
# Data fetched for ROK
# Debug - Ticker: ROL, DataFrame shape: (250, 1)
# Data fetched for ROL
# Debug - Ticker: ROP, DataFrame shape: (250, 1)
# Data fetched for ROP
# Debug - Ticker: ROST, DataFrame shape: (250, 1)
# Data fetched for ROST
# Debug - Ticker: RCL, DataFrame shape: (250, 1)
# Data fetched for RCL
# Debug - Ticker: SPGI, DataFrame shape: (250, 1)
# Data fetched for SPGI
# Debug - Ticker: CRM, DataFrame shape: (250, 1)
# Data fetched for CRM
# Debug - Ticker: SBAC, DataFrame shape: (250, 1)
# Data fetched for SBAC
# Debug - Ticker: SLB, DataFrame shape: (250, 1)
# Data fetched for SLB
# Debug - Ticker: STX, DataFrame shape: (250, 1)
# Data fetched for STX
# Debug - Ticker: SRE, DataFrame shape: (250, 1)
# Data fetched for SRE
# Debug - Ticker: NOW, DataFrame shape: (250, 1)
# Data fetched for NOW
# Debug - Ticker: SHW, DataFrame shape: (250, 1)
# Data fetched for SHW
# Debug - Ticker: SPG, DataFrame shape: (250, 1)
# Data fetched for SPG
# Debug - Ticker: SWKS, DataFrame shape: (250, 1)
# Data fetched for SWKS
# Debug - Ticker: SJM, DataFrame shape: (250, 1)
# Data fetched for SJM
# Debug - Ticker: SNA, DataFrame shape: (250, 1)
# Data fetched for SNA
# Debug - Ticker: SO, DataFrame shape: (250, 1)
# Data fetched for SO
# Debug - Ticker: LUV, DataFrame shape: (250, 1)
# Data fetched for LUV
# Debug - Ticker: SWK, DataFrame shape: (250, 1)
# Data fetched for SWK
# Debug - Ticker: SBUX, DataFrame shape: (250, 1)
# Data fetched for SBUX
# Debug - Ticker: STT, DataFrame shape: (250, 1)
# Data fetched for STT
# Debug - Ticker: STLD, DataFrame shape: (250, 1)
# Data fetched for STLD
# Debug - Ticker: STE, DataFrame shape: (250, 1)
# Data fetched for STE
# Debug - Ticker: SYK, DataFrame shape: (250, 1)
# Data fetched for SYK
# Debug - Ticker: SYF, DataFrame shape: (250, 1)
# Data fetched for SYF
# Debug - Ticker: SNPS, DataFrame shape: (250, 1)
# Data fetched for SNPS
# Debug - Ticker: SYY, DataFrame shape: (250, 1)
# Data fetched for SYY
# Debug - Ticker: TMUS, DataFrame shape: (250, 1)
# Data fetched for TMUS
# Debug - Ticker: TROW, DataFrame shape: (250, 1)
# Data fetched for TROW
# Debug - Ticker: TTWO, DataFrame shape: (250, 1)
# Data fetched for TTWO
# Debug - Ticker: TPR, DataFrame shape: (250, 1)
# Data fetched for TPR
# Debug - Ticker: TRGP, DataFrame shape: (250, 1)
# Data fetched for TRGP
# Debug - Ticker: TGT, DataFrame shape: (250, 1)
# Data fetched for TGT
# Debug - Ticker: TEL, DataFrame shape: (250, 1)
# Data fetched for TEL
# Debug - Ticker: TDY, DataFrame shape: (250, 1)
# Data fetched for TDY
# Debug - Ticker: TFX, DataFrame shape: (250, 1)
# Data fetched for TFX
# Debug - Ticker: TER, DataFrame shape: (250, 1)
# Data fetched for TER
# Debug - Ticker: TSLA, DataFrame shape: (250, 1)
# Data fetched for TSLA
# Debug - Ticker: TXN, DataFrame shape: (250, 1)
# Data fetched for TXN
# Debug - Ticker: TXT, DataFrame shape: (250, 1)
# Data fetched for TXT
# Debug - Ticker: TMO, DataFrame shape: (250, 1)
# Data fetched for TMO
# Debug - Ticker: TJX, DataFrame shape: (250, 1)
# Data fetched for TJX
# Debug - Ticker: TSCO, DataFrame shape: (250, 1)
# Data fetched for TSCO
# Debug - Ticker: TT, DataFrame shape: (250, 1)
# Data fetched for TT
# Debug - Ticker: TDG, DataFrame shape: (250, 1)
# Data fetched for TDG
# Debug - Ticker: TRV, DataFrame shape: (250, 1)
# Data fetched for TRV
# Debug - Ticker: TRMB, DataFrame shape: (250, 1)
# Data fetched for TRMB
# Debug - Ticker: TFC, DataFrame shape: (250, 1)
# Data fetched for TFC
# Debug - Ticker: TYL, DataFrame shape: (250, 1)
# Data fetched for TYL
# Debug - Ticker: TSN, DataFrame shape: (250, 1)
# Data fetched for TSN
# Debug - Ticker: USB, DataFrame shape: (250, 1)
# Data fetched for USB
# Debug - Ticker: UDR, DataFrame shape: (250, 1)
# Data fetched for UDR
# Debug - Ticker: ULTA, DataFrame shape: (250, 1)
# Data fetched for ULTA
# Debug - Ticker: UNP, DataFrame shape: (250, 1)
# Data fetched for UNP
# Debug - Ticker: UAL, DataFrame shape: (250, 1)
# Data fetched for UAL
# Debug - Ticker: UPS, DataFrame shape: (250, 1)
# Data fetched for UPS
# Debug - Ticker: URI, DataFrame shape: (250, 1)
# Data fetched for URI
# Debug - Ticker: UNH, DataFrame shape: (250, 1)
# Data fetched for UNH
# Debug - Ticker: UHS, DataFrame shape: (250, 1)
# Data fetched for UHS
# Debug - Ticker: VLO, DataFrame shape: (250, 1)
# Data fetched for VLO
# Debug - Ticker: VTR, DataFrame shape: (250, 1)
# Data fetched for VTR
# Debug - Ticker: VRSN, DataFrame shape: (250, 1)
# Data fetched for VRSN
# Debug - Ticker: VRSK, DataFrame shape: (250, 1)
# Data fetched for VRSK
# Debug - Ticker: VZ, DataFrame shape: (250, 1)
# Data fetched for VZ
# Debug - Ticker: VRTX, DataFrame shape: (250, 1)
# Data fetched for VRTX
# Debug - Ticker: VFC, DataFrame shape: (250, 1)
# Data fetched for VFC
# Debug - Ticker: VTRS, DataFrame shape: (250, 1)
# Data fetched for VTRS
# Debug - Ticker: VICI, DataFrame shape: (250, 1)
# Data fetched for VICI
# Debug - Ticker: V, DataFrame shape: (250, 1)
# Data fetched for V
# Debug - Ticker: VMC, DataFrame shape: (250, 1)
# Data fetched for VMC
# Debug - Ticker: WRB, DataFrame shape: (250, 1)
# Data fetched for WRB
# Debug - Ticker: WAB, DataFrame shape: (250, 1)
# Data fetched for WAB
# Debug - Ticker: WBA, DataFrame shape: (250, 1)
# Data fetched for WBA
# Debug - Ticker: WMT, DataFrame shape: (250, 1)
# Data fetched for WMT
# Debug - Ticker: DIS, DataFrame shape: (250, 1)
# Data fetched for DIS
# Debug - Ticker: WBD, DataFrame shape: (250, 1)
# Data fetched for WBD
# Debug - Ticker: WM, DataFrame shape: (250, 1)
# Data fetched for WM
# Debug - Ticker: WAT, DataFrame shape: (250, 1)
# Data fetched for WAT
# Debug - Ticker: WEC, DataFrame shape: (250, 1)
# Data fetched for WEC
# Debug - Ticker: WFC, DataFrame shape: (250, 1)
# Data fetched for WFC
# Debug - Ticker: WELL, DataFrame shape: (250, 1)
# Data fetched for WELL
# Debug - Ticker: WST, DataFrame shape: (250, 1)
# Data fetched for WST
# Debug - Ticker: WDC, DataFrame shape: (250, 1)
# Data fetched for WDC
# Debug - Ticker: WRK, DataFrame shape: (250, 1)
# Data fetched for WRK
# Debug - Ticker: WY, DataFrame shape: (250, 1)
# Data fetched for WY
# Debug - Ticker: WHR, DataFrame shape: (250, 1)
# Data fetched for WHR
# Debug - Ticker: WMB, DataFrame shape: (250, 1)
# Data fetched for WMB
# Debug - Ticker: WTW, DataFrame shape: (250, 1)
# Data fetched for WTW
# Debug - Ticker: GWW, DataFrame shape: (250, 1)
# Data fetched for GWW
# Debug - Ticker: WYNN, DataFrame shape: (250, 1)
# Data fetched for WYNN
# Debug - Ticker: XEL, DataFrame shape: (250, 1)
# Data fetched for XEL
# Debug - Ticker: XYL, DataFrame shape: (250, 1)
# Data fetched for XYL
# Debug - Ticker: YUM, DataFrame shape: (250, 1)
# Data fetched for YUM
# Debug - Ticker: ZBRA, DataFrame shape: (250, 1)
# Data fetched for ZBRA
# Debug - Ticker: ZBH, DataFrame shape: (250, 1)
# Data fetched for ZBH
# Debug - Ticker: ZION, DataFrame shape: (250, 1)
# Data fetched for ZION
# Debug - Ticker: ZTS, DataFrame shape: (250, 1)
# Data fetched for ZTS
#                                     Close Symbol Security  GICS Sector
#     Date
# MMM 2023-01-03 00:00:00-05:00  115.488167    MMM       3M  Industrials
#     2023-01-04 00:00:00-05:00  118.015373    MMM       3M  Industrials
#     2023-01-05 00:00:00-05:00  115.950233    MMM       3M  Industrials
#     2023-01-06 00:00:00-05:00  119.495872    MMM       3M  Industrials
#     2023-01-09 00:00:00-05:00  119.561882    MMM       3M  Industrials

# %%
# Out:
# 2

# %%
#REF 
#import pandas as pd 
#import yfinance as yf 

#url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

#read tables into PD dataframe 
#dfs = pd.read_html(url) 

#get first table (index 0) + first 3 cols 
#df = dfs[0].iloc[:, :3] 
#print(df)
